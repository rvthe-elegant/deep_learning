# %% [markdown]
# <a href="https://colab.research.google.com/github/rvthe-elegant/deep_learning/blob/Assignment_2/DL_Assign2_Activity2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 20MAI0038 - Rahul Laxman Vasanad

# %%
# Supress Warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Questions:2
# 1. filter size (3*3)
# 2. filter size (5*5)
# 3. filter size (3*3), stride=2
# 4. filter size (5*5), stride=2
# 5. filter size (3*3),stride=1, zero-padding
# 6. filter size (5*5),stride=1, zero-padding
# 7. Entropy

# %%
# Import the required packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Conv2D
import skimage.measure

# %%
#Importing the image

from PIL import Image
image=Image.open('/content/vit.jfif')
plt.imshow(image)

# %%
# 25,25,3 rows,columns,scale(here 3: red green blue, 1: gray scale)

rsize = image.resize((np.array((15,15))).astype(int))
image = np.asarray(rsize)
image.shape
# Out:
# (15, 15, 3)

# %%
#Puting the image into an array
x=image.reshape(1,15,15,3)

# %%
def Convolution(x,kernel_size,strides=1, padding='valid'):
 model=Sequential()
 model.add(Conv2D(1, kernel_size=kernel_size,strides=strides,padding=padding,input_shape=(15,15,3)))
 yhat = model.predict(x)
 y=yhat.reshape(yhat.shape[1],yhat.shape[2])
 filtered_image = Image.fromarray(y)
 return filtered_image

# %%
#As per as the question given above
Filtered_image_11=Convolution(x,(3,3))
Filtered_image_12=Convolution(x,(5,5))
Filtered_image_21=Convolution(x,(3,3),2)
Filtered_image_22=Convolution(x,(5,5),2)
Filtered_image_31=Convolution(x,(3,3),1,'same')
Filtered_image_32=Convolution(x,(5,5),1,'same')
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7efba02769e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %% [markdown]
# 1. filter size (3*3)

# %%
plt.imshow(Filtered_image_11)
entropy = skimage.measure.shannon_entropy(Filtered_image_11)
entropy = skimage.measure.shannon_entropy(Filtered_image_11)
print("Entropy:",entropy)
# Out:
# Entropy: 7.400879436282184

# %% [markdown]
# 2. filter size (5*5)

# %%
plt.imshow(Filtered_image_12)
entropy = skimage.measure.shannon_entropy(Filtered_image_12)
entropy = skimage.measure.shannon_entropy(Filtered_image_12)
print("Entropy:",entropy)
# Out:
# Entropy: 6.918863237274594

# %% [markdown]
# 3. filter size (3*3), stride=2

# %%
plt.imshow(Filtered_image_21)
entropy = skimage.measure.shannon_entropy(Filtered_image_21)
entropy = skimage.measure.shannon_entropy(Filtered_image_21)
print("Entropy:",entropy)
# Out:
# Entropy: 5.614709844115208

# %% [markdown]
# 4. filter size (5*5), stride=2

# %%
 plt.imshow(Filtered_image_22)
entropy = skimage.measure.shannon_entropy(Filtered_image_22)
entropy = skimage.measure.shannon_entropy(Filtered_image_22)
print("Entropy:",entropy)
# Out:
# Entropy: 5.169925001442313

# %% [markdown]
# 5. filter size (3*3),stride=1, zero-padding

# %%
plt.imshow(Filtered_image_31)
entropy = skimage.measure.shannon_entropy(Filtered_image_31)
entropy = skimage.measure.shannon_entropy(Filtered_image_31)
print("Entropy:",entropy)
# Out:
# Entropy: 7.81378119121704

# %% [markdown]
# 6. filter size (5*5),stride=1, zero-padding

# %%
plt.imshow(Filtered_image_32)
entropy = skimage.measure.shannon_entropy(Filtered_image_32)
entropy = skimage.measure.shannon_entropy(Filtered_image_32)
print("Entropy:",entropy)
# Out:
# Entropy: 7.81378119121704
